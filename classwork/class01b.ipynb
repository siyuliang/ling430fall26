# %% [markdown]
# LING 430 Fall 2026
#
# lecture 01b
#
# in-class activity

# %% [markdown]
# #### Python basics

# %%
word = 'hola'

# %%
word

# %%
2word = "hola”

# %%
print("hello, LING 430!")

# %%
len("Odyssey")

# %%
len("Krung Thep Maha Nakhon Amon Rattanakosin Mahintharayutthaya Mahadilok Phop Noppharat Ratchathani Burirom Udomratchaniwet Mahasathan Amon Phiman Awatan Sathit Sakkathattiya Witsanukam Prasit")

# %%
type("Odyssey")

# %%
print("ha" * 3)

# %% [markdown]
# #### functions vs methods

# %%
"Odyssey".lower()

# %%
line = "Tell me, O Muse, of that ingenious hero"
line.split()

# %%
set("banana")

# %%
print(word)

# %% [markdown]
# #### activity

# %%
# 1. pick a word in any language: print it and count its characters according to Python
my_word = ""

# %%
# 2. predict all three lines first, then run.
print("rose" * 3)
print(len("a b c"))
"rose" + 3   # read the error, then put a # in front of this line

# %%
# 3. how many words in this sentence? how many different words?
stein = "Rose is a rose is a rose is a rose"
