# %% [markdown]
# LING 430 Fall 2026
#
# lecture 02a
#
# in-class activity

# %% [markdown]
# #### variables & types

# %%
num = 17
num_add = num + 4
num_add

# %%
num = 3
num

# %%
type("Odyssey")

# %%
type(7)

# %%
x = 17
type(x)

# %%
x = "seventeen"
type(x)

# %%
float(3)

# %%
int("42")

# %%
int(42.1)

# %%
str(42)

# %%
round(2/3, 2)

# %% [markdown]
# #### numbers

# %%
6 * 7

# %%
84 / 2

# %%
2 ** 10

# %%
7 // 4

# %%
7 % 4

# %%
7 > 4

# %%
len("Odyssey") == 7

# %%
"rose" != "Rose"

# %% [markdown]
# #### strings

# %%
s1 = "a string in double quotes contains 'single quotes' happily"
s2 = 'and vice "versa"'
print(s1)
print(s2)

# %%
print("line one\nline two")

# %%
print("word\tgloss")

# %%
"un" + "happy"

# %%
"ha" * 3

# %%
len("unhappy")

# %%
"ppy" in "unhappy"

# %%
word = "duckling"
word[0]

# %%
word[-1]

# %%
word[0:4]

# %%
word[4:8]

# %%
word[:4]

# %%
word[4:]

# %%
word[:-1]

# %%
word[::-1]

# %%
s = "rice"
s[0] = "n"   # read the error, then put a # in front of this line

# %%
s = "n" + s[1:]
s

# %% [markdown]
# #### exercise

# %%
# classical greek builds the perfect like this:
#      luo  "I release"    ->  leluka  "I have released"
#      thuo "I sacrifice"  ->  tethuka "I have sacrificed"
#    write code that builds the perfect from the present form
word = "luo"

# %% [markdown]
# #### list

# %%
myList = [123, 'spam', 1.23]
birds = ["duck", "goose", "swan"]
empty = []

# %%
line = "colorless green ideas sleep furiously"
tokens = line.split()
type(tokens)

# %%
len(tokens)

# %%
tokens[0]

# %%
tokens[-1]

# %%
tokens[1:3]

# %%
glosses = [["inu", "dog"], ["neko", "cat"], ["tori", "bird"]]
glosses[1]

# %%
glosses[1][0]

# %%
x = ['a', 'b', 'c']
x.append('d')
x[2] = 'e'
x

# %%
a = ["ba"]
b = a
a.append("baa")
b

# %% [markdown]
# #### pop-up quiz

# %%
# predict every output first
myList = ["a", "b", [1, 2, 3], "d", "e"]
myList[3] = [4, 5, 6]

# %%
print(myList[1])

# %%
print(myList[2][0])

# %%
print(myList[5])

# %%
# how would you access the integer 5?

# %% [markdown]
# #### answers

# %%
# exercise
word = "luo"
first_consonant = word[0]        # "l"
word_without_o = word[0:-1]      # "lu"
print(first_consonant + "e" + word_without_o + "ka")

word = "thuo"
print(word[0] + "e" + word[0:-1] + "ka")   # tethuka -- te-, not the-

# %%
# quiz
# myList[1] -> "b"; myList[2][0] -> 1; myList[5] -> IndexError
# the 5 is at myList[3][1]
