# %% [markdown]
# LING 430 Fall 2026
#
# HW1
#
# Due Thursday Sep 10, 11:59 pm, submit on Canvas

# %% [markdown]
# submission guidelines:
# - type your answers and code directly into the cells
# - before submitting, run the notebook top to bottom (Runtime > Run all) and check that no cell errors out
# - download the notebook and submit on Canvas under Assignments > HW1
# - keeping or clearing your outputs are both fine

# %% [markdown]
# #### AI usage
#
# if applicable, list any AI tools you used for this homework, what you asked them, and where the result went into your work. if you used none, write "none".
#
# declaration:

# %% [markdown]
# #### warm-up

# %%
# 1. print a variable called 'laughter' made of 10 ha's

# %%
# 2. print how many characters this word has
word = "antidisestablishmentarianism"

# %%
# 3. print the first and the last character of word

# %%
# 4. write an expression that checks whether "establish" appears in word

# %% [markdown]
# #### string surgery

# %%
# 1. spanish marks gender with a final vowel: amigo "friend (m)" -> amiga "friend (f)"
#    derive amiga from amigo with a slice and +
word = "amigo"

# %%
# 2. derive "unhappiness" from the three pieces below, then pull each piece back
#    out of your result with slices
prefix = "un"
stem = "happy"   # careful: the y changes
suffix = "ness"

# %%
# 3. write one line that tests whether a word reads the same backwards
#    (tip: you can try it on "level" and "duck")

# %% [markdown]
# #### words and lines

# %%
# 1. store the four lines below in one variable called poem, using triple quotes
#    (Robert Frost, 1923)
#
#    The woods are lovely, dark and deep,
#    But I have promises to keep,
#    And miles to go before I sleep,
#    And miles to go before I sleep.

# %%
# 2. run these two cells and compare the outputs
poem

# %%
print(poem)

# %%
poem.split()

# %%
# 3. .split() gave you the words. find out how to split poem into its four
#    lines instead (look it up anywhere you like) and do it here

# %% [markdown]
# 1. `poem` and `print(poem)` display your string differently. what is `\n`, and how did it get into the variable when you never typed it?
# 2. in class, `.split()` broke a string at spaces. look closely at the output of `poem.split()`: what happened at the ends of the lines, and what does `.split()` really treat as a boundary?
# 3. what did you search for or ask to solve exercise 3, and how did you check that what you found actually worked?
# 4. name one kind of language data where the line, not the word, is the unit you would want to keep.
#
# answer:
