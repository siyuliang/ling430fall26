# %% [markdown]
# LING 430 Fall 2026
#
# HW2
#
# Due Thursday Sep 17, 11:59 pm, submit on Canvas

# %% [markdown]
# submission guidelines:
# - save a copy of this file in your own Drive
# - type your answers and code directly into the cells
# - download the notebook and submit on Canvas under Assignments > HW2
# - keeping or clearing your outputs are both fine

# %% [markdown]
# #### AI usage
#
# if applicable, list any AI tools you used for this homework, what you asked them, and where the result went into your work. if you used none, write "none".
#
# declaration:

# %% [markdown]
# #### palindrome

# %%
# 1. write clean(s). it takes one string and returns a new string:
#    the same text lowercased, with every character in ignore removed.
#      clean("Madam, I'm Adam.")   ->   'madamimadam'
#      clean("level")              ->   'level'
#    build the new string by looping over the characters of s and keeping
#    the ones that are not in ignore.
ignore = " ,.!?'\"-"

def clean(s):
    ...

# %%
# 2. write is_palindrome(s). it takes one string, cleans it with clean(),
#    and returns True or False: True when the cleaned string is the same
#    read forwards and backwards, False when it is not.
#      is_palindrome("Madam, I'm Adam.")        ->   True
#      is_palindrome("the chef made her duck")  ->   False

def is_palindrome(s):
    ...

# %%
# run this cell to check your work.
# the first four should print True, and the last one False.
for s in ["level", "A Santa lived as a devil at NASA", "Madam, I'm Adam.",
          "Eva, can I stab bats in a cave?", "the chef made her duck"]:
    print(is_palindrome(s), s)

# %% [markdown]
# #### other writing systems

# %%
# run this cell to test your checker on other writing systems
# three of them will pass and one will fail.
tests = ["たけやぶやけた", # Japanese, "the bamboo grove burned (down)"
         "上海自来水来自海上", # Chinese, "Shanghai tap water comes from the sea"
         "Νίψον ἀνομήματα μὴ μόναν ὄψιν", # Greek, "wash your sins, not only your face", Byzantine inscription
         "ربك فكبر"] # Arabic, "and your lord, magnify.", Quran 74:3
for s in tests:
    print(is_palindrome(s), s)

# %% [markdown]
# your `clean()` decides what to ignore and what counts as the same character. write those decisions down as a numbered list of rules, then answer with 2-3 sentences each:
#
# 1. for the one sentence that fails, compare its letters from the outside in: what would `clean()` have to treat as the same character for it to pass? can you think of a language where that same decision would destroy a real contrast?
# 2. which of your rules is *meaningless*, rather than merely wrong, for one of these scripts or any other scripts you know of? you may look up relevant information online for this question.
#
# answer:

# %% [markdown]
# #### filestream

# %%
# you can finish this question in the current cell or in different cells.
#    a) replace "REPLACE WITH YOURS" in the list with one additional palindrone and one additional non-palindrone of your choice
#    a) write all strings in candidates to candidates.txt, one string per line.
#    b) read candidates.txt back with .readlines()
#    c) print each sentence in candidates.txt with their is_palindrome() value using f-string.
#            e.g. "Madam, I'm Adam." is a palindrone? True!
#    note: 
#    be careful about the newline character.
candidates = ["level",
              "Was it a car or a cat I saw?",
              "colorless green ideas sleep furiously",
              "REPLACE WITH YOURS",
              "REPLACE WITH YOURS"]
