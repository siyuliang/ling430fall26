# %% [markdown]
# LING 430 Fall 2026
#
# HW3
#
# Due Thursday Oct 1, 11:59 pm, submit on Canvas

# %% [markdown]
# submission guidelines:
# - save a copy of this file in your own Drive
# - type your answers and code directly into the cells
# - download the notebook and submit on Canvas under Assignments > HW3
# - keeping or clearing your outputs are both fine

# %% [markdown]
# #### AI usage
#
# if applicable, list any AI tools you used for this homework, what you asked them, and where the result went into your work. if you used none, write "none".
#
# declaration:

# %% [markdown]
# #### Japanese verb morphology
#
# Japanese builds causatives ('make someone X') and passives on the verb stem:
#
# | stem | gloss | causative | passive | causative-passive |
# |---|---|---|---|---|
# | tabe | eat | tabe-sase | tabe-rare | tabe-sase-rare |
# | mi | see | mi-sase | mi-rare | mi-sase-rare |
#
# suffix order is fixed: causative before passive, never the reverse.

# %%
lexicon = {"tabe": "eat", "mi": "see", "oki": "wake up", "ake": "open"}

CAUS = "sase"
PASS = "rare"

# %%
# 1. write causative(stem), passive(stem), and causative_passive(stem)
#    each returns the suffixed form with hyphens, e.g. "tabe-sase"
#    build the form with an f-string, e.g. f"{stem}-{CAUS}"
def causative(stem):
    return

# %%
# 2. generate all four forms (plain, causative, passive, causative-passive)
#    for every stem in the lexicon, with its gloss
#    you should have a total of 16 lines of output
for stem in lexicon:
    gloss = lexicon[stem]
    # print the four forms here, one per line, each with its gloss

# %% [markdown]
# #### consonant stems
#
# for consonant-final stems the suffixes begin differently: *kak* 'write' → *kak-ase*, *kak-are*.

# %%
# 3. extend your functions: if the stem ends in a consonant, use "ase"/"are"
#    instead of "sase"/"rare". add kak "write" and yom "read" to the lexicon
#    and regenerate all forms.
#    tip: stem[-1] is the last letter, and stem[-1] in "aeiou" tests whether it is a vowel
def causative(stem):
    if stem[-1] in "aeiou":
        return 
    else:
        return

# %%
# 4. spelling cleanup with a regex: Japanese is usually romanized in the Hepburn system,
#    which spells si as shi and ti as chi. finish the function and apply it to your outputs,
#    so that e.g. a stem like "hanasi" comes out "hanashi"
import re

def hepburn(form):
    # one re.sub for si, one for ti
    return form

hepburn("hanasi")

# %% [markdown]
# #### analysis
#
# answer each question in ~5 sentences.
#
# 1. based on what we covered in class, what can you say about Japanese in terms of its morphological typology? use the forms you generated as evidence.
# 2. which properties of Japanese morphology make it easy for a computer to process, and which make it difficult? point to specific parts of your code where you can.
#
# answer:
